# %%
from global_health_data_visualizer.global_health_data_visualizer import DataVisualizer

# %%
file_path = 'data/safelySanitization.csv'

# Instantiate the DataVisualizer class
visualizer = DataVisualizer(file_path)

visualizer.data.head()
# Out:
#   Location                                          Indicator  Period   Dim1  \
# 0  Albania  Population using safely managed sanitation ser...    2017  Total
# 1  Albania  Population using safely managed sanitation ser...    2017  Urban
# 2  Albania  Population using safely managed sanitation ser...    2017  Rural
# 3  Albania  Population using safely managed sanitation ser...    2016  Total
# 4  Albania  Population using safely managed sanitation ser...    2016  Urban
#
#    First Tooltip
# 0          39.86
# 1          40.17
# 2          39.39
# 3          39.85
# 4          40.17

# %%
visualizer.plot_first_tooltip_by_location(visualizer,2017, None, ["China","Austria","Djibouti"])

# %%
visualizer.lineplot(visualizer,"China")

# %%
visualizer.scatterplot(visualizer, "China")

# %%
visualizer.barplot(visualizer, "China")

# %%
visualizer.create_health_map_multilayer(visualizer, initial_year=2013)
# Out:
# /Users/xinranbi/Desktop/sds-271-fp/global_health_data_visualizer/global_health_data_visualizer.py:203: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
# VBox(children=(IntSlider(value=2013, description='Year', max=2017, min=2000), Output()))

# %%
visualizer.create_health_map(visualizer, initial_year=2013)
# Out:
# /Users/xinranbi/Desktop/sds-271-fp/global_health_data_visualizer/global_health_data_visualizer.py:255: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
# VBox(children=(IntSlider(value=2013, description='Year', max=2017, min=2000), Output()))

# %%
visualizer.aggregate_data_by_region_and_year(visualizer)
# Out:
#     Region                                          Indicator  Period   Dim1  \
# 0      AFR  Population using safely managed sanitation ser...    2000  Rural
# 1      AFR  Population using safely managed sanitation ser...    2000  Total
# 2      AFR  Population using safely managed sanitation ser...    2000  Urban
# 3      AFR  Population using safely managed sanitation ser...    2001  Rural
# 4      AFR  Population using safely managed sanitation ser...    2001  Total
# ..     ...                                                ...     ...    ...
# 283    WPR  Population using safely managed sanitation ser...    2016  Total
# 284    WPR  Population using safely managed sanitation ser...    2016  Urban
# 285    WPR  Population using safely managed sanitation ser...    2017  Rural
# 286    WPR  Population using safely managed sanitation ser...    2017  Total
# 287    WPR  Population using safely managed sanitation ser...    2017  Urban
#
#      First Tooltip
# 0         9.173750
# 1        12.785000
# 2        16.948571
# 3         9.507500
# 4        13.041667
# ..             ...
# 283      69.218889
# 284      55.134000
# 285      41.565000
# 286      70.024444
# 287      55.922000
#
# [288 rows x 5 columns]

# %%
visualizer.lineplot(visualizer,location="AFR")

# %%
help(visualizer)
# Out:
# Help on DataVisualizer in module global_health_data_visualizer.global_health_data_visualizer object:
#
# class DataVisualizer(builtins.object)
#  |  DataVisualizer(csv_file)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, csv_file)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  aggregate_data_by_region_and_year(self)
#  |
#  |  aggregate_years(data)
#  |      # barplot
#  |
#  |  barplot(self, location)
#  |
#  |  check_same_entries_in_Indicator(self)
#  |      checks whether all entries in the 'Indicator' column are identical
#  |
#  |  create_health_map(self, initial_year)
#  |
#  |  create_health_map_multilayer(self, initial_year)
#  |
#  |  lineplot(self, location)
#  |
#  |  plot_first_tooltip_by_location(self, period, column_name=None, location=None)
#  |      Plot the value of "First Tooltip" for Dim1 = 'Total' at a designated period for different locations.
#  |      In particular, if column_name is not provided and all entries in the 'Indicator' column are identical,
#  |      it uses the first entry in the 'Indicator' column as the column name.
#  |      If the 'Dim1' column includes categories 'Urban', 'Total', and 'Rural', the function proceeds with plotting;
#  |      otherwise, it notifies that the 'Dim1' column does not meet the specified criteria.
#  |
#  |  scatterplot(self, location)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
